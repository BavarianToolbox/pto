# %%
#| hide
from pto.core import *

# %% [markdown]
# # pto
#
# > Class-agnostic prompted single object localization

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install pto
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Train EfficientNet PyTorch models for class-agnostic prompted single object localization.

# %%
1+1
# Out:
# 2
